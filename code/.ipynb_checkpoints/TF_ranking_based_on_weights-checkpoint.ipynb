# %% [markdown]
# # Step 3: Evaluate weights and derived GRNs

# %%
# %matplotlib inline

import pickle
import matplotlib.pyplot as plt
import numpy as np
import ipdb
import copy
plt.rcParams['figure.dpi'] = 150

# %%
p2saved_file = '/data/jianhao/hepatocyte_update_dataset_101619/new_results_with_monoc_NF_100'
num_target_genes = 1000
num_TFs = 200

with open(p2saved_file, 'rb') as f:
    results_all = pickle.load(f)
    
results_all.keys()
# Out:
# dict_keys(['weight_dic', 'adjusted_r_squared', 'standard_error', 'TF_ids', 'query_targets'])

# %%
weight_dic = results_all['weight_dic']
TF_ids = results_all['TF_ids']
target_ids = results_all['query_targets']
print('length of TF: ',len(TF_ids))

for label in weight_dic:
    print(weight_dic[label].shape)
    break
# Out:
# length of TF:  200
# (201, 1000)

# %% [markdown]
# # sort by ranking

# %%
def array_to_rank(in_arr):
    '''
    The bigger the element, the higher rank (larger number in ranks list)
    '''
    np_arr = np.array(in_arr)
    tmp = (np_arr).argsort()
    ranks = np.empty_like(tmp)
    ranks[tmp] = np.arange(len(np_arr))
    return ranks

def sort_TF_by_ranking(weight_dic, TF_ids, top_k = 5):
    '''
    weight_dic: {label: weight_mat}
    weight_mat: num_TF * num_target
    '''
    len_of_TF = len(TF_ids)
    weight_dic_new = copy.deepcopy(weight_dic)
    for label in weight_dic_new:
        weight_mat = np.abs(weight_dic_new[label])
        for col_idx in range(weight_mat.shape[1]):
            w_vector = weight_mat[:len_of_TF, col_idx]
            ranks = array_to_rank(w_vector)
            weight_dic_new[label][:len_of_TF, col_idx] = ranks
    
    # drop the bias term in weight_mat.
    for label in weight_dic_new:
        weight_mat = weight_dic_new[label]
        weight_dic_new[label] = weight_mat[:len_of_TF, :]
    
    # sort TFs based on their average ranking
    TF_importance = {}
    for label in weight_dic_new:
        
        average_importance = weight_dic_new[label].mean(axis = 1)
        tmp = average_importance.argsort()
        topk_TF = [TF_ids[x] for x in tmp[:top_k]]
        
        fig, ax = plt.subplots()
        im = ax.imshow(weight_dic_new[label] <= top_k)
        ax.set_xlabel('target index')
        ax.set_ylabel('TF ids')
        ax.set_yticks(tmp[:top_k])
        ax.set_yticklabels(topk_TF)
        ax.set_title('cluster label {}'.format(label))
        plt.show()
        
        rank_TF = array_to_rank(-average_importance)
        TF_importance[label] = {}
        TF_importance[label]['TF_average_importance'] = average_importance
        TF_importance[label]['TF_ranking'] = rank_TF
        TF_importance[label]['top k TFs'] = topk_TF
    return TF_importance, weight_dic_new

# %%
test_arr = [5, 2, 4, 1]
test_rank = array_to_rank(test_arr)
print(test_rank)
# Out:
# [0 2 1 3]

# %%
TF_ranking, weight_dic_ranking = sort_TF_by_ranking(weight_dic, TF_ids, 50)
# print(weight_dic_ranking)

# %%
list_of_important_TF = []
for label in TF_ranking:
    print([label])
    print(TF_ranking[label]['top k TFs'])
    for tf in TF_ranking[label]['top k TFs']:
        list_of_important_TF.append(tf)
# Out:
# [1]
# ['ATF5', 'CEBPB', 'JUND', 'CREB3L3', 'PPARA', 'TSC22D1', 'ZBTB20', 'HNF4A', 'YBX1', 'CEBPA', 'TFDP2', 'XBP1', 'FOXQ1', 'ID2', 'NR3C1', 'PEG3', 'KLF15', 'NR1I3', 'ID3', 'HHEX', 'PROX1', 'YBX3', 'NR0B2', 'SREBF1', 'NR1H3', 'KLF13', 'TCF25', 'HBP1', 'NR2F6', 'ONECUT2', 'HOPX', 'NONO', 'PURB', 'SMARCA5', 'FOXA3', 'RXRA', 'BHLHE40', 'SSRP1', 'ATF4', 'ZFP91', 'NFIX', 'TSC22D3', 'NFIB', 'EGR1', 'USF2', 'SALL1', 'JUNB', 'MAFG', 'MXD4', 'KLF9']
# [2]
# ['ZBTB20', 'ATF5', 'CEBPB', 'ID3', 'YBX1', 'JUND', 'CEBPA', 'HNF4A', 'PPARA', 'CREB3L3', 'TSC22D1', 'ID2', 'NR1I3', 'TFDP2', 'HOPX', 'HHEX', 'XBP1', 'DBP', 'HES6', 'PHF5A', 'SREBF1', 'NR2F6', 'FOXQ1', 'CREM', 'NR1H3', 'NR3C1', 'MLX', 'ID1', 'FOXA3', 'EPAS1', 'GATAD1', 'TFAM', 'PEG3', 'NONO', 'KLF9', 'RXRA', 'KLF15', 'TCF25', 'NR0B2', 'SMARCE1', 'NR1H4', 'SMARCA5', 'RORA', 'DNAJC2', 'ZFP91', 'PURA', 'NR1D1', 'BHLHE40', 'USF2', 'HMG20B']
# [3]
# ['CEBPB', 'JUND', 'ZBTB20', 'CREB3L3', 'YBX1', 'ID2', 'CEBPA', 'ATF5', 'TFDP2', 'XBP1', 'ID3', 'TSC22D1', 'DBP', 'HHEX', 'PPARA', 'ONECUT2', 'NR1I3', 'HNF4A', 'SREBF1', 'NFIA', 'FOXQ1', 'HOPX', 'HES6', 'NR0B2', 'TCF25', 'ID1', 'PEG3', 'KLF15', 'NR3C1', 'ZFP91', 'YBX3', 'NR1H4', 'NCOR1', 'NR1H3', 'FOXA3', 'NR2F6', 'BHLHE40', 'EPAS1', 'MBD1', 'SMARCA5', 'MLX', 'NFIX', 'ARID5B', 'NONO', 'STAT1', 'KLF9', 'IRF2', 'TFAM', 'ATF6', 'TSC22D3']
# [4]
# ['ZBTB20', 'CEBPB', 'ATF5', 'CEBPA', 'JUND', 'CREB3L3', 'YBX1', 'SREBF1', 'XBP1', 'NFIA', 'ONECUT2', 'ID3', 'PPARA', 'NCOR1', 'TFDP2', 'HHEX', 'RORA', 'NR1I3', 'PROX1', 'HOPX', 'FOXQ1', 'NR1H4', 'FOXA3', 'KLF15', 'ID2', 'ZFP91', 'KLF9', 'PHF5A', 'NFIC', 'TCF25', 'HNF4A', 'HES6', 'DBP', 'TSC22D1', 'EGR1', 'PURA', 'NFIX', 'MLX', 'NR2F6', 'TFAM', 'MIER1', 'BCL3', 'SMARCE1', 'RXRA', 'NR1H3', 'YBX3', 'GATAD1', 'JUNB', 'CREM', 'CEBPG']
# [5]
# ['CEBPB', 'CEBPA', 'ATF5', 'YBX1', 'XBP1', 'CREB3L3', 'JUND', 'ZBTB20', 'ID3', 'DBP', 'HHEX', 'NR1I3', 'TFDP2', 'ID2', 'SREBF1', 'HNF4A', 'PPARA', 'HOPX', 'ZFP91', 'PHF5A', 'TSC22D1', 'HES6', 'FOXA3', 'TCF25', 'NCOR1', 'MLX', 'TFAM', 'CREM', 'NR1H4', 'RORA', 'ONECUT2', 'GATAD1', 'FOXQ1', 'ID1', 'DNAJC2', 'NR2F6', 'USF2', 'SMARCE1', 'CEBPD', 'CEBPG', 'RXRA', 'ARID5B', 'NFIA', 'FOXN3', 'SMARCC2', 'HMG20B', 'PURA', 'KLF15', 'STAT1', 'SMARCA5']
# [6]
# ['YBX1', 'CEBPB', 'CEBPA', 'ZBTB20', 'DBP', 'ATF5', 'JUND', 'XBP1', 'HHEX', 'HNF4A', 'NR1I3', 'ID2', 'CREB3L3', 'PHF5A', 'ID3', 'HOPX', 'PPARA', 'TSC22D1', 'HES6', 'GATAD1', 'NR2F6', 'SFPQ', 'CREM', 'TFAM', 'NR0B2', 'FOXQ1', 'ID1', 'RXRA', 'RORA', 'SMARCE1', 'TCF25', 'MLX', 'SREBF1', 'LYAR', 'FOXA3', 'STAT3', 'KLF15', 'BHLHE40', 'TFDP2', 'LRRFIP2', 'EPAS1', 'PEG3', 'NFIA', 'ARID5B', 'DNAJC2', 'NR1H4', 'NFIX', 'NR1H3', 'SMARCA5', 'ZFP91']
# [7]
# ['JUND', 'YBX1', 'CEBPB', 'ZBTB20', 'CEBPA', 'XBP1', 'CREB3L3', 'ATF5', 'HHEX', 'ID3', 'HNF4A', 'TCF25', 'GATAD1', 'FOXQ1', 'ONECUT2', 'EGR1', 'NFIA', 'SREBF1', 'DBP', 'HOPX', 'PHF5A', 'PROX1', 'ID2', 'TFDP2', 'HES6', 'KLF15', 'NFIB', 'KLF9', 'NFIC', 'SFPQ', 'NR1H4', 'TSC22D1', 'NR1I3', 'RXRA', 'PPARA', 'USF2', 'AHR', 'ZFP91', 'RORA', 'ID1', 'SMARCA5', 'NR0B2', 'NFYB', 'ZFHX3', 'PBRM1', 'TSC22D3', 'NONO', 'FOXN3', 'BHLHE40', 'STAT3']
# [8]
# ['YBX1', 'CEBPB', 'CEBPA', 'DBP', 'PHF5A', 'ATF5', 'NR1I3', 'ID2', 'JUND', 'ZBTB20', 'XBP1', 'ID3', 'GATAD1', 'HNF4A', 'CREB3L3', 'HHEX', 'HOPX', 'PPARA', 'TFAM', 'SFPQ', 'NR2F6', 'HES6', 'RXRA', 'NCOR1', 'TSC22D1', 'ZFP91', 'NFIA', 'CREM', 'FOXQ1', 'ONECUT2', 'LYAR', 'SREBF1', 'SMARCA5', 'ID1', 'LRRFIP2', 'NR0B2', 'NONO', 'TCF25', 'SMARCE1', 'SSRP1', 'YBX3', 'RORA', 'PROX1', 'DNAJC2', 'TFDP2', 'CEBPG', 'STAT3', 'UBTF', 'NR1H3', 'NFKBIA']
# [9]
# ['CEBPA', 'CEBPB', 'ZBTB20', 'YBX1', 'ATF5', 'JUND', 'NR1I3', 'ID3', 'CREB3L3', 'XBP1', 'HHEX', 'ID2', 'PPARA', 'DBP', 'HNF4A', 'TSC22D1', 'HOPX', 'PHF5A', 'HES6', 'SREBF1', 'CREM', 'NR2F6', 'MLX', 'FOXQ1', 'KLF15', 'GATAD1', 'SMARCE1', 'NR1H3', 'ID1', 'RXRA', 'NR0B2', 'NR1H4', 'NR3C1', 'DNAJC2', 'LYAR', 'FOXA3', 'TCF25', 'ONECUT2', 'SMARCA5', 'USF2', 'TFAM', 'LRRFIP2', 'PURA', 'PROX1', 'EPAS1', 'AHR', 'BHLHE40', 'STAT3', 'ZFP91', 'NFIB']

# %%
union_of_TFs = set(list_of_important_TF)
print(union_of_TFs)
index_of_union_TF = [TF_ids.index(tf) for tf in union_of_TFs]
print(index_of_union_TF)
print([TF_ids[x] for x in index_of_union_TF])
print(len(union_of_TFs))
# Out:
# {'MBD1', 'HES6', 'ONECUT2', 'BHLHE40', 'JUNB', 'TFAM', 'GATAD1', 'YBX3', 'NCOR1', 'PEG3', 'STAT1', 'MLX', 'CEBPD', 'HOPX', 'TSC22D1', 'RORA', 'PURA', 'NR0B2', 'PHF5A', 'YBX1', 'LYAR', 'KLF9', 'ZBTB20', 'MXD4', 'HBP1', 'LRRFIP2', 'NFIC', 'TSC22D3', 'NR1I3', 'IRF2', 'PROX1', 'HHEX', 'ID3', 'TFDP2', 'NFKBIA', 'NONO', 'MAFG', 'FOXN3', 'JUND', 'ZFHX3', 'KLF13', 'ID2', 'FOXQ1', 'NR3C1', 'SMARCE1', 'ATF4', 'SMARCC2', 'HNF4A', 'KLF15', 'RXRA', 'TCF25', 'USF2', 'CREB3L3', 'ARID5B', 'AHR', 'PURB', 'BCL3', 'SALL1', 'NR1H4', 'ZFP91', 'NFIB', 'XBP1', 'STAT3', 'ID1', 'NR1H3', 'FOXA3', 'SREBF1', 'CEBPB', 'NFIX', 'SFPQ', 'MIER1', 'PPARA', 'CEBPA', 'HMG20B', 'ATF5', 'PBRM1', 'SSRP1', 'CREM', 'NR1D1', 'EGR1', 'EPAS1', 'CEBPG', 'ATF6', 'NR2F6', 'DBP', 'UBTF', 'DNAJC2', 'NFIA', 'SMARCA5', 'NFYB'}
# [191, 3, 188, 66, 110, 91, 49, 69, 139, 73, 1, 147, 174, 55, 123, 128, 186, 45, 169, 42, 52, 196, 178, 51, 157, 133, 95, 31, 7, 103, 8, 197, 47, 130, 159, 29, 150, 162, 105, 114, 83, 156, 153, 187, 144, 167, 101, 25, 64, 11, 117, 77, 92, 90, 158, 137, 75, 111, 97, 195, 38, 136, 146, 21, 17, 74, 138, 26, 109, 44, 41, 171, 79, 94, 80, 120, 16, 184, 142, 185, 183, 78, 6, 106, 82, 148, 50, 40, 108, 96]
# ['MBD1', 'HES6', 'ONECUT2', 'BHLHE40', 'JUNB', 'TFAM', 'GATAD1', 'YBX3', 'NCOR1', 'PEG3', 'STAT1', 'MLX', 'CEBPD', 'HOPX', 'TSC22D1', 'RORA', 'PURA', 'NR0B2', 'PHF5A', 'YBX1', 'LYAR', 'KLF9', 'ZBTB20', 'MXD4', 'HBP1', 'LRRFIP2', 'NFIC', 'TSC22D3', 'NR1I3', 'IRF2', 'PROX1', 'HHEX', 'ID3', 'TFDP2', 'NFKBIA', 'NONO', 'MAFG', 'FOXN3', 'JUND', 'ZFHX3', 'KLF13', 'ID2', 'FOXQ1', 'NR3C1', 'SMARCE1', 'ATF4', 'SMARCC2', 'HNF4A', 'KLF15', 'RXRA', 'TCF25', 'USF2', 'CREB3L3', 'ARID5B', 'AHR', 'PURB', 'BCL3', 'SALL1', 'NR1H4', 'ZFP91', 'NFIB', 'XBP1', 'STAT3', 'ID1', 'NR1H3', 'FOXA3', 'SREBF1', 'CEBPB', 'NFIX', 'SFPQ', 'MIER1', 'PPARA', 'CEBPA', 'HMG20B', 'ATF5', 'PBRM1', 'SSRP1', 'CREM', 'NR1D1', 'EGR1', 'EPAS1', 'CEBPG', 'ATF6', 'NR2F6', 'DBP', 'UBTF', 'DNAJC2', 'NFIA', 'SMARCA5', 'NFYB']
# 90

# %%
change_of_ranking_mat = np.empty((len(index_of_union_TF), len(TF_ranking)))
for label in TF_ranking:
    tmp = TF_ranking[label]['TF_ranking']
    union_TF = tmp[index_of_union_TF]
    change_of_ranking_mat[:, label - 1] = -union_TF

fig, ax = plt.subplots(dpi = 300)
ax.imshow(change_of_ranking_mat)
ax.set_yticks(range(len(index_of_union_TF)))
ax.set_yticklabels([TF_ids[x] for x in index_of_union_TF], fontsize = 4)
ax.set_xticks(range(len(TF_ranking)))
ax.set_xticklabels([x + 1 for x in range(len(TF_ranking))], fontsize = 4)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
# fig=plt.figure(dpi = 500)
# plt.rcParams['figure.figsize'] = [20, 5]
# plt.rcParams.update({'font.size': 14})
plt.show()

# %%
change_of_ranking_mat = np.empty((len(index_of_union_TF), len(TF_ranking)))
for label in TF_ranking:
    tmp = TF_ranking[label]['TF_average_importance']
    union_TF = tmp[index_of_union_TF]
    change_of_ranking_mat[:, label - 1] = union_TF

fig, ax = plt.subplots()
ax.imshow(change_of_ranking_mat)
ax.set_yticks(range(len(index_of_union_TF)))
ax.set_yticklabels([TF_ids[x] for x in index_of_union_TF])
ax.set_xticks(range(len(TF_ranking)))
ax.set_xticklabels(x + 1 for x in range(len(TF_ranking)))
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
plt.show()

# %% [markdown]
# # sort by weights

# %%
def sort_TF_by_weights(weight_dic, TF_ids, top_k = 5):
    len_of_TF = len(TF_ids)
    weight_dic_new = copy.deepcopy(weight_dic)
    
    # drop the bias term in weight_mat.
    for label in weight_dic_new:
        weight_mat = np.abs(weight_dic_new[label])
        weight_dic_new[label] = weight_mat[:len_of_TF, :]
    
    # sort TFs based on their average weights
    TF_importance = {}
    for label in weight_dic_new:
        
        average_importance = weight_dic_new[label].mean(axis = 1)
        # argsort uses ascending order
        tmp = (-average_importance).argsort()
        topk_TF = [TF_ids[x] for x in tmp[:top_k]]
        
        fig, ax = plt.subplots()
        im = ax.imshow(weight_dic_new[label] > weight_dic_new[label].mean())
        ax.set_xlabel('target index')
        ax.set_ylabel('TF ids')
        ax.set_yticks(tmp[:top_k])
        ax.set_yticklabels(topk_TF)
        ax.set_title('cluster label {}'.format(label))
        plt.show()
        
        rank_TF = array_to_rank(-average_importance)
        TF_importance[label] = {}
        TF_importance[label]['TF_average_importance'] = average_importance
        TF_importance[label]['TF_ranking'] = rank_TF
        TF_importance[label]['top k TFs'] = topk_TF
    return TF_importance, weight_dic_new

# %%
TF_ranking, weight_dic_ranking = sort_TF_by_weights(weight_dic, TF_ids, 10)

# %%
list_of_important_TF = []
for label in TF_ranking:
    print(int2label_dict[label])
    print(TF_ranking[label]['top k TFs'])
    for tf in TF_ranking[label]['top k TFs']:
        list_of_important_TF.append(tf)
# Out:
# PN14
# ['ATF5', 'NR1H3', 'CEBPB', 'CREB3L3', 'TCF25', 'SREBF1', 'PHF5A', 'JUND', 'HNF4A', 'YBX1']
# Adult
# ['ZBTB20', 'CEBPA', 'CEBPB', 'NFIA', 'JUND', 'CREB3L3', 'EGR1', 'YBX1', 'PHF5A', 'ID2']
# PHx24
# ['CEBPB', 'ZBTB20', 'ATF5', 'YBX1', 'XBP1', 'PHF5A', 'HOPX', 'JUND', 'GATAD1', 'NFIA']
# PHx48
# ['CEBPB', 'PHF5A', 'YBX1', 'ZBTB20', 'ID3', 'XBP1', 'ATF5', 'NR1I3', 'HOPX', 'JUND']
# PHx96
# ['ATF5', 'NR1I3', 'CEBPB', 'ZBTB20', 'PHF5A', 'JUND', 'YBX1', 'XBP1', 'ONECUT2', 'NR2F6']

# %%
union_of_TFs = set(list_of_important_TF)
print(union_of_TFs)
index_of_union_TF = [TF_ids.index(tf) for tf in union_of_TFs]
print(index_of_union_TF)
print([TF_ids[x] for x in index_of_union_TF])
# Out:
# {'ZBTB20', 'XBP1', 'CEBPB', 'CEBPA', 'SREBF1', 'EGR1', 'TCF25', 'NFIA', 'ID3', 'NR1I3', 'PHF5A', 'NR2F6', 'YBX1', 'NR1H3', 'HOPX', 'CREB3L3', 'ID2', 'ONECUT2', 'ATF5', 'GATAD1', 'JUND', 'HNF4A'}
# [178, 136, 26, 78, 138, 185, 117, 40, 47, 7, 167, 107, 42, 17, 55, 93, 155, 188, 80, 48, 106, 25]
# ['ZBTB20', 'XBP1', 'CEBPB', 'CEBPA', 'SREBF1', 'EGR1', 'TCF25', 'NFIA', 'ID3', 'NR1I3', 'PHF5A', 'NR2F6', 'YBX1', 'NR1H3', 'HOPX', 'CREB3L3', 'ID2', 'ONECUT2', 'ATF5', 'GATAD1', 'JUND', 'HNF4A']

# %%
change_of_ranking_mat = np.empty((len(index_of_union_TF), len(TF_ranking)))
for label in TF_ranking:
    tmp = TF_ranking[label]['TF_ranking']
    union_TF = tmp[index_of_union_TF]
    change_of_ranking_mat[:, label] = union_TF

fig, ax = plt.subplots()
ax.imshow(change_of_ranking_mat)
ax.set_yticks(range(len(index_of_union_TF)))
ax.set_yticklabels([TF_ids[x] for x in index_of_union_TF])
ax.set_xticks(range(len(TF_ranking)))
ax.set_xticklabels([int2label_dict[x] for x in range(len(TF_ranking))])
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
plt.show()

# %%
change_of_ranking_mat = np.empty((len(index_of_union_TF), len(TF_ranking)))
for label in TF_ranking:
    tmp = TF_ranking[label]['TF_average_importance']
    union_TF = tmp[index_of_union_TF]
    change_of_ranking_mat[:, label] = -union_TF

fig, ax = plt.subplots()
ax.imshow(change_of_ranking_mat)
ax.set_yticks(range(len(index_of_union_TF)))
ax.set_yticklabels([TF_ids[x] for x in index_of_union_TF])
ax.set_xticks(range(len(TF_ranking)))
ax.set_xticklabels([int2label_dict[x] for x in range(len(TF_ranking))])
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
plt.show()
